# %% [markdown]
# ### DMD Ingredient->Product Lookup
#
# Get a list of all VMPs (Virtual Medicinal Products) and AMPs (Actual Medicinal Products) from a given list of ingredients (VTMs = Virtual Therapeutic Moieties)

# %%
# set name of codelist for exporting file
codelist_name="rheumatology_meds"


# import or paste list of vtms (Virtual Therapeutic Moieties / Ingredients) by name
names = ['Adalimumab', 'Etanercept', 'Certolizumab', 'Infliximab', 'Golimumab','Rituximab',
        'Tocilizumab','Sarilumab','Tofacitinib','Baricitinib','Upadacitinib','Filgotinib',
        'Abatacept','Ipilimumab','Nivolumab','Pembrolizumab']


from ebmdatalab import bq
import os
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ## Select products from DMD containing chosen ingredients

# %%
# convert list to tuple for use in SQL query
names_tuple = tuple(names)
if len(names_tuple)==1:
    # remove comma if only one item
    names_tuple = str(names_tuple).replace(",","")

sql = f'''
SELECT "vmp" AS type, vmp.id, bnf_code, vmp.nm, ing.nm AS ingredient, ddd.ddd
FROM dmd.vmp
INNER JOIN dmd.vpi AS vpi ON vmp.id=vpi.vmp 
INNER JOIN dmd.ing as ing ON ing.id = vpi.ing AND ing.nm IN {names_tuple}
LEFT JOIN dmd.ddd on vmp.id=ddd.vpid

ORDER BY type, nm  '''

meds = bq.cached_read(sql, csv_path=os.path.join('..','data',f'meds_{codelist_name}.csv'))

meds.count()
# Out:
# type          54
# id            54
# bnf_code      48
# nm            54
# ingredient    54
# ddd           38
# dtype: int64

# %% [markdown]
# #### Add wildcards to all ingredients and append any results to csv output

# %%
#Create a tuple containing all ingredients with wildcards (%) to pull back ingredients 
# with prefix and suffix words

append_suff = '%\''
append_pref = '\'%'

wc_ings =  [append_pref + i + append_suff for i in names]


wc_ing_tup = tuple(wc_ings)

wc_ing_tup
# Out:
# ("'%Adalimumab%'",
#  "'%Etanercept%'",
#  "'%Certolizumab%'",
#  "'%Infliximab%'",
#  "'%Golimumab%'",
#  "'%Rituximab%'",
#  "'%Tocilizumab%'",
#  "'%Sarilumab%'",
#  "'%Tofacitinib%'",
#  "'%Baricitinib%'",
#  "'%Upadacitinib%'",
#  "'%Filgotinib%'",
#  "'%Abatacept%'",
#  "'%Ipilimumab%'",
#  "'%Nivolumab%'",
#  "'%Pembrolizumab%'")

# %%
# Create a variable for each of the missing ingredients making sure there are the matching number of 
# ingredients to test variables, ie/ 4 ingredients will require 0,1,2,3 to be called from the 

WC_ing_0 = str(wc_ing_tup[0])
WC_ing_1 = str(wc_ing_tup[1])
WC_ing_2 = str(wc_ing_tup[2])
WC_ing_3 = str(wc_ing_tup[3])
WC_ing_4 = str(wc_ing_tup[4])
WC_ing_5 = str(wc_ing_tup[5])
WC_ing_6 = str(wc_ing_tup[6])
WC_ing_7 = str(wc_ing_tup[7])
WC_ing_8 = str(wc_ing_tup[8])
WC_ing_9 = str(wc_ing_tup[9])
WC_ing_10 = str(wc_ing_tup[10])
WC_ing_11 = str(wc_ing_tup[11])
WC_ing_12 = str(wc_ing_tup[12])
WC_ing_13 = str(wc_ing_tup[13])
WC_ing_14 = str(wc_ing_tup[14])
WC_ing_15 = str(wc_ing_tup[15])

WC_missing_ing_sql = f'''
SELECT *
FROM dmd.ing
where ing.nm like {WC_ing_0}
    or ing.nm like {WC_ing_1}
    or ing.nm like {WC_ing_2}
    or ing.nm like {WC_ing_3}
    or ing.nm like {WC_ing_4}
    or ing.nm like {WC_ing_5}
    or ing.nm like {WC_ing_6}
    or ing.nm like {WC_ing_7}
    or ing.nm like {WC_ing_8}
    or ing.nm like {WC_ing_9}
    or ing.nm like {WC_ing_10}
    or ing.nm like {WC_ing_11}
    or ing.nm like {WC_ing_12}
    or ing.nm like {WC_ing_13}
    or ing.nm like {WC_ing_14}
    or ing.nm like {WC_ing_15}


ORDER BY nm  '''
WC_missing_ing_tbl = bq.cached_read(WC_missing_ing_sql, 
                csv_path=os.path.join('..','data',f'meds_{codelist_name}.csv'))

WC_missing_ing_tbl
# Out:
#                    id     isiddt      isidprev  invalid  \
# 0           421777009        NaT           NaN    False
# 1           407317001 2005-07-27  5.015611e+15    False
# 2           726518002 2017-10-06  3.430661e+16    False
# 3           430306004        NaT           NaN    False
# 4           387045004 2005-07-29  4.173811e+15    False
# 5   39002911000001106        NaT           NaN    False
# 6   39039711000001109        NaT           NaN    False
# 7           442435002        NaT           NaN    False
# 8           386891004 2005-08-01  4.428711e+15    False
# 9           697995005 2018-01-25  1.937301e+16    False
# 10          704191007 2015-05-28  2.974571e+16    False
# 11          716125002 2016-11-18  2.998861e+16    False
# 12          386919002 2005-08-03  7.694611e+15    False
# 13  34666611000001109        NaT           NaN    False
# 14          444648007 2010-10-07  1.607671e+16    False
# 15          704313003        NaT           NaN    False
# 16          704314009        NaT           NaN    False
# 17  37800211000001108        NaT           NaN    False
# 18  37949711000001108        NaT           NaN    False
#
#                           nm
# 0                  Abatacept
# 1                 Adalimumab
# 2                Baricitinib
# 3         Certolizumab pegol
# 4                 Etanercept
# 5                 Filgotinib
# 6         Filgotinib maleate
# 7                  Golimumab
# 8                 Infliximab
# 9                 Ipilimumab
# 10                 Nivolumab
# 11             Pembrolizumab
# 12                 Rituximab
# 13                 Sarilumab
# 14               Tocilizumab
# 15               Tofacitinib
# 16       Tofacitinib citrate
# 17              Upadacitinib
# 18  Upadacitinib hemihydrate

# %% [markdown]
# #### Create final list including wildcard ingredient names for ingredients with no exact matches

# %%
sql_incl_wc_match = f'''
SELECT "vmp" AS type, vmp.id, bnf_code, vmp.nm, ing.nm AS ingredient, ddd.ddd
FROM dmd.vmp
INNER JOIN dmd.vpi AS vpi ON vmp.id=vpi.vmp 
INNER JOIN dmd.ing as ing ON ing.id = vpi.ing AND ing.nm IN {names_tuple}
LEFT JOIN dmd.ddd on vmp.id=ddd.vpid

UNION DISTINCT

SELECT "vmp" AS type, vmp.id, bnf_code, vmp.nm, ing.nm AS ingredient, ddd.ddd
FROM dmd.vmp
INNER JOIN dmd.vpi AS vpi ON vmp.id=vpi.vmp 
INNER JOIN dmd.ing as ing ON ing.id = vpi.ing 
LEFT JOIN dmd.ddd on vmp.id=ddd.vpid
WHERE ing.nm LIKE {WC_ing_0}
    OR ing.nm LIKE {WC_ing_1}
    OR ing.nm LIKE {WC_ing_2}
    OR ing.nm LIKE {WC_ing_3}

  '''

meds_incl_wc_match = bq.cached_read(sql_incl_wc_match
            , csv_path=os.path.join('..','data',f'meds_{codelist_name}.csv'))

meds_incl_wc_match
# Out:
#    type                 id         bnf_code  \
# 0   vmp  30033011000001108  0801050CAAAAAAA
# 1   vmp  11762011000001101  1001030V0AAAAAA
# 2   vmp  36065611000001101  1001030D0AAAAAA
# 3   vmp  36065711000001105  1001030D0AAABAB
# 4   vmp  19946811000001101  1001030D0AAAFAF
# 5   vmp  34346011000001104  1001030ACAAAAAA
# 6   vmp  34625211000001109  1001030ACAAABAB
# 7   vmp          400687000  1001030T0AAAAAA
# 8   vmp  35894411000001100  1001030S0AAAAAA
# 9   vmp  11236911000001103  1001030S0AAABAB
# 10  vmp  19697711000001100  1001030S0AAACAC
# 11  vmp  32888111000001102  1001030S0AAADAD
# 12  vmp  32888211000001108  1001030S0AAAEAE
# 13  vmp  35318811000001108  1001030S0AAAFAF
# 14  vmp  36458011000001101  1001030S0AAAGAG
# 15  vmp  36457911000001103  1001030S0AAAHAH
# 16  vmp  36441711000001106  1001030S0AAAIAI
# 17  vmp  29889211000001106  0802040ATAAAAAA
# 18  vmp  29889111000001100  0802040ATAAABAB
# 19  vmp  35541811000001105  0802040ATAAACAC
# 20  vmp  16101911000001101  1001030W0AAABAB
# 21  vmp  16102111000001109  1001030W0AAAAAA
# 22  vmp  16102011000001108  1001030W0AAACAC
# 23  vmp  24856911000001102  1001030W0AAADAD
# 24  vmp  35431611000001103  1001030W0AAAEAE
# 25  vmp  34378411000001105  0801050CAAAABAB
# 26  vmp  34742611000001106  1001030ADAAAAAA
# 27  vmp  34742811000001105  1001030ADAAABAB
# 28  vmp  34742511000001107  1001030ADAAACAC
# 29  vmp  34742711000001102  1001030ADAAADAD
# 30  vmp  35934711000001107  0802030F0AAABAB
# 31  vmp  35934811000001104  0802030F0AAAAAA
# 32  vmp  24856511000001109  0802030F0AAACAC
# 33  vmp  37829011000001101             None
# 34  vmp  37829111000001100             None
# 35  vmp  37829211000001106             None
# 36  vmp  37829311000001103             None
# 37  vmp  37829511000001109             None
# 38  vmp  37829611000001108             None
# 39  vmp  21704711000001107  1001030V0AAABAB
# 40  vmp  29767011000001106  1001030V0AAACAC
# 41  vmp  37223111000001105  1001030V0AAADAD
# 42  vmp  37223011000001109  1001030V0AAAEAE
# 43  vmp  10970211000001102  1001030D0AAACAC
# 44  vmp  11034511000001106  1001030D0AAADAD
# 45  vmp  15987111000001107  1001030D0AAAEAE
# 46  vmp  34840511000001108  1001030D0AAAGAG
# 47  vmp  18038111000001100  1001030X0AAAAAA
# 48  vmp  18038011000001101  1001030X0AAABAB
# 49  vmp  23984711000001106  1001030X0AAACAC
# 50  vmp  38196111000001103  1001030T0AAACAC
# 51  vmp  38196011000001104  1001030T0AAABAB
# 52  vmp  19448611000001101  0801050BCAAAAAA
# 53  vmp  19448511000001100  0801050BCAAABAB
# 54  vmp  33523711000001105  1001030Y0AAABAB
# 55  vmp  17315811000001100  1001030Y0AAAAAA
# 56  vmp  37854811000001107  1001030Y0AAACAC
#
#                                                                                    nm  \
# 0                           Pembrolizumab 50mg powder for solution for infusion vials
# 1                              Abatacept 250mg powder for solution for infusion vials
# 2                 Etanercept 25mg powder and solvent for solution for injection vials
# 3                 Etanercept 50mg powder and solvent for solution for injection vials
# 4                 Etanercept 10mg powder and solvent for solution for injection vials
# 5                                                             Baricitinib 4mg tablets
# 6                                                             Baricitinib 2mg tablets
# 7                             Infliximab 100mg powder for solution for infusion vials
# 8                    Adalimumab 40mg/0.8ml solution for injection pre-filled syringes
# 9          Adalimumab 40mg/0.8ml solution for injection pre-filled disposable devices
# 10                                 Adalimumab 40mg/0.8ml solution for injection vials
# 11         Adalimumab 40mg/0.4ml solution for injection pre-filled disposable devices
# 12                   Adalimumab 40mg/0.4ml solution for injection pre-filled syringes
# 13                   Adalimumab 20mg/0.2ml solution for injection pre-filled syringes
# 14                   Adalimumab 80mg/0.8ml solution for injection pre-filled syringes
# 15         Adalimumab 80mg/0.8ml solution for injection pre-filled disposable devices
# 16                   Adalimumab 20mg/0.4ml solution for injection pre-filled syringes
# 17                                     Nivolumab 40mg/4ml solution for infusion vials
# 18                                   Nivolumab 100mg/10ml solution for infusion vials
# 19                                   Nivolumab 240mg/24ml solution for infusion vials
# 20                                 Tocilizumab 200mg/10ml solution for infusion vials
# 21                                   Tocilizumab 80mg/4ml solution for infusion vials
# 22                                 Tocilizumab 400mg/20ml solution for infusion vials
# 23                 Tocilizumab 162mg/0.9ml solution for injection pre-filled syringes
# 24       Tocilizumab 162mg/0.9ml solution for injection pre-filled disposable devices
# 25                                Pembrolizumab 100mg/4ml solution for infusion vials
# 26                  Sarilumab 150mg/1.14ml solution for injection pre-filled syringes
# 27                  Sarilumab 200mg/1.14ml solution for injection pre-filled syringes
# 28        Sarilumab 150mg/1.14ml solution for injection pre-filled disposable devices
# 29        Sarilumab 200mg/1.14ml solution for injection pre-filled disposable devices
# 30                                   Rituximab 100mg/10ml solution for infusion vials
# 31                                   Rituximab 500mg/50ml solution for infusion vials
# 32                                 Rituximab 1.4g/11.7ml solution for injection vials
# 33                       Rituximab 1000mg/500ml in Sodium chloride 0.9% infusion bags
# 34                        Rituximab 500mg/500ml in Sodium chloride 0.9% infusion bags
# 35                        Rituximab 600mg/500ml in Sodium chloride 0.9% infusion bags
# 36                        Rituximab 700mg/500ml in Sodium chloride 0.9% infusion bags
# 37                        Rituximab 800mg/500ml in Sodium chloride 0.9% infusion bags
# 38                        Rituximab 900mg/500ml in Sodium chloride 0.9% infusion bags
# 39                     Abatacept 125mg/1ml solution for injection pre-filled syringes
# 40           Abatacept 125mg/1ml solution for injection pre-filled disposable devices
# 41                  Abatacept 87.5mg/0.7ml solution for injection pre-filled syringes
# 42                    Abatacept 50mg/0.4ml solution for injection pre-filled syringes
# 43                     Etanercept 50mg/1ml solution for injection pre-filled syringes
# 44                   Etanercept 25mg/0.5ml solution for injection pre-filled syringes
# 45           Etanercept 50mg/1ml solution for injection pre-filled disposable devices
# 46         Etanercept 25mg/0.5ml solution for injection pre-filled disposable devices
# 47                    Golimumab 50mg/0.5ml solution for injection pre-filled syringes
# 48          Golimumab 50mg/0.5ml solution for injection pre-filled disposable devices
# 49           Golimumab 100mg/1ml solution for injection pre-filled disposable devices
# 50                    Infliximab 120mg/1ml solution for injection pre-filled syringes
# 51          Infliximab 120mg/1ml solution for injection pre-filled disposable devices
# 52                                   Ipilimumab 50mg/10ml solution for infusion vials
# 53                                  Ipilimumab 200mg/40ml solution for infusion vials
# 54  Certolizumab pegol 200mg/1ml solution for injection pre-filled disposable devices
# 55            Certolizumab pegol 200mg/1ml solution for injection pre-filled syringes
# 56                     Certolizumab pegol 200mg/1ml solution for injection cartridges
#
#             ingredient    ddd
# 0        Pembrolizumab    NaN
# 1            Abatacept  27.00
# 2           Etanercept   7.00
# 3           Etanercept   7.00
# 4           Etanercept   7.00
# 5          Baricitinib   4.00
# 6          Baricitinib   4.00
# 7           Infliximab   3.75
# 8           Adalimumab   2.90
# 9           Adalimumab   2.90
# 10          Adalimumab   2.90
# 11          Adalimumab   2.90
# 12          Adalimumab   2.90
# 13          Adalimumab   2.90
# 14          Adalimumab   2.90
# 15          Adalimumab   2.90
# 16          Adalimumab   2.90
# 17           Nivolumab    NaN
# 18           Nivolumab    NaN
# 19           Nivolumab    NaN
# 20         Tocilizumab  20.00
# 21         Tocilizumab  20.00
# 22         Tocilizumab  20.00
# 23         Tocilizumab  20.00
# 24         Tocilizumab  20.00
# 25       Pembrolizumab    NaN
# 26           Sarilumab  14.30
# 27           Sarilumab  14.30
# 28           Sarilumab  14.30
# 29           Sarilumab  14.30
# 30           Rituximab    NaN
# 31           Rituximab    NaN
# 32           Rituximab    NaN
# 33           Rituximab    NaN
# 34           Rituximab    NaN
# 35           Rituximab    NaN
# 36           Rituximab    NaN
# 37           Rituximab    NaN
# 38           Rituximab    NaN
# 39           Abatacept  27.00
# 40           Abatacept  27.00
# 41           Abatacept  27.00
# 42           Abatacept  27.00
# 43          Etanercept   7.00
# 44          Etanercept   7.00
# 45          Etanercept   7.00
# 46          Etanercept   7.00
# 47           Golimumab   1.66
# 48           Golimumab   1.66
# 49           Golimumab   1.66
# 50          Infliximab   3.75
# 51          Infliximab   3.75
# 52          Ipilimumab    NaN
# 53          Ipilimumab    NaN
# 54  Certolizumab pegol  14.00
# 55  Certolizumab pegol  14.00
# 56  Certolizumab pegol  14.00

# %% [markdown]
# ### Results

# %%
# How many products have DDDs using exact match
print(meds[["ddd", "id"]].count())

# How many products have DDDs using wildcard matching
print(meds_incl_wc_match[["ddd", "id"]].count())
# Out:
# ddd    38
# id     54
# dtype: int64
# ddd    41
# id     57
# dtype: int64

# %%
#Exact and non exact (including wildcards) ingredient name matches
meds_incl_wc_match

# %%
#Exact ingredient name match only
meds
