# %% [markdown]
# ### DMD Ingredient->Product Lookup
#
# Get a list of all VMPs (Virtual Medicinal Products) and AMPs (Actual Medicinal Products) from a given list of ingredients (VTMs = Virtual Therapeutic Moieties)

# %%
# set name of codelist for exporting file
codelist_name="rheumatology_meds"


# import or paste list of vtms (Virtual Therapeutic Moieties / Ingredients) by name
names = ['Adalimumab', 'Etanercept', 'Certolizumab', 'Infliximab', 'Golimumab','Rituximab',
        'Tocilizumab','Sarilumab','Tofacitinib','Baricitinib','Upadacitinib','Filgotinib',
        'Abatacept','Ipilimumab','Nivolumab','Pembrolizumab']


from ebmdatalab import bq
import os
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ## Select products from DMD containing chosen ingredients

# %%
# convert list to tuple for use in SQL query
names_tuple = tuple(names)
if len(names_tuple)==1:
    # remove comma if only one item
    names_tuple = str(names_tuple).replace(",","")

sql = f'''
SELECT "vmp" AS type, vmp.id, bnf_code, vmp.nm, ing.nm AS ingredient, ddd.ddd
FROM dmd.vmp
INNER JOIN dmd.vpi AS vpi ON vmp.id=vpi.vmp 
INNER JOIN dmd.ing as ing ON ing.id = vpi.ing AND ing.nm IN {names_tuple}
LEFT JOIN dmd.ddd on vmp.id=ddd.vpid

ORDER BY type, nm  '''

meds = bq.cached_read(sql, csv_path=os.path.join('..','data',f'meds_{codelist_name}.csv'))

meds.count()
# Out:
# type          54
# id            54
# bnf_code      48
# nm            54
# ingredient    54
# ddd           38
# dtype: int64

# %% [markdown]
# #### Check if any ingredients were not found

# %%
ings = list(meds.ingredient.drop_duplicates())
names.sort()
ings.sort()
print("Selected ingredients:", names)
print("Ingredients found:", ings)

missing_ings = [i for i in names if i not in ings]
print("Ingredients NOT found:", missing_ings)
# Out:
# Selected ingredients: ['Abatacept', 'Adalimumab', 'Baricitinib', 'Certolizumab', 'Etanercept', 'Filgotinib', 'Golimumab', 'Infliximab', 'Ipilimumab', 'Nivolumab', 'Pembrolizumab', 'Rituximab', 'Sarilumab', 'Tocilizumab', 'Tofacitinib', 'Upadacitinib']
# Ingredients found: ['Abatacept', 'Adalimumab', 'Baricitinib', 'Etanercept', 'Golimumab', 'Infliximab', 'Ipilimumab', 'Nivolumab', 'Pembrolizumab', 'Rituximab', 'Sarilumab', 'Tocilizumab']
# Ingredients NOT found: ['Certolizumab', 'Filgotinib', 'Tofacitinib', 'Upadacitinib']

# %% [markdown]
# #### Investigate ingredients not found using wildcards to find non-exact matches

# %%
#WORKING - search for missing ingredient name with wildcard, to look for names with suffix or prefix
# if present, add 'nm' to the updated ing list and rerun below 
# The above is a work around approach as don't currently have code which uses wildcard searching 

search_term = '"%Filgotinib%"'

missing_ing_sql = f'''
SELECT *
FROM dmd.ing
where ing.nm like {search_term}

ORDER BY nm  '''

single_ing_missing_tbl = bq.cached_read(missing_ing_sql, 
                csv_path=os.path.join('..','data',f'meds_{codelist_name}.csv'))
               

single_ing_missing_tbl
# Out:
#                   id isiddt  isidprev  invalid                  nm
# 0  39002911000001106    NaT       NaN    False          Filgotinib
# 1  39039711000001109    NaT       NaN    False  Filgotinib maleate

# %%
#WORKING - look for id's of missing ing's found in the targetted wildcard search above in vpi table
#Result - some ingredients are present only with a prefix/suffix in the vpi table
#Action - add the full ing names not previously included to the revised code list below 

missing_ids = tuple(single_ing_missing_tbl.id)

vpi_sql = f'''
SELECT *
FROM dmd.vpi
where ing IN {missing_ids}

ORDER BY ing  '''

vpi_missing_tbl = bq.cached_read(vpi_sql, 
                csv_path=os.path.join('..','data',f'meds_{codelist_name}.csv'))
               

vpi_missing_tbl
# Out:
#                  vmp                ing  basis_strnt           bs_subid  \
# 0  39046311000001104  39039711000001109            2  39002911000001106
# 1  39046211000001107  39039711000001109            2  39002911000001106
#
#   strnt_nmrtr_val  strnt_nmrtr_uom strnt_dnmtr_val  strnt_dnmtr_uom
# 0   200.000000000        258684004            None              NaN
# 1   100.000000000        258684004            None              NaN

# %% [markdown]
# #### Add wildcards to missing ingredients and append any results to csv output

# %%
#Create a tuple containing all missing ingredients with wildcards (%) to pull back ingredients 
# with prefix and suffix words

append_suff = '%\''
append_pref = '\'%'

wc_missing_ings =  [append_pref + i + append_suff for i in missing_ings]


wc_missing_ing_tup = tuple(wc_missing_ings)

wc_missing_ing_tup
# Out:
# ("'%Certolizumab%'", "'%Filgotinib%'", "'%Tofacitinib%'", "'%Upadacitinib%'")

# %%
# Create a variable for each of the missing ingredients making sure there are the matching number of 
# ingredients to test variables, ie/ 4 ingredients will require 0,1,2,3 to be called from the 

WC_ing_0 = str(wc_missing_ing_tup[0])
WC_ing_1 = str(wc_missing_ing_tup[1])
WC_ing_2 = str(wc_missing_ing_tup[2])
WC_ing_3 = str(wc_missing_ing_tup[3])


WC_missing_ing_sql = f'''
SELECT *
FROM dmd.ing
where ing.nm like {WC_ing_0}
    or ing.nm like {WC_ing_1}
    or ing.nm like {WC_ing_2}
    or ing.nm like {WC_ing_3}

ORDER BY nm  '''
WC_missing_ing_tbl = bq.cached_read(WC_missing_ing_sql, 
                csv_path=os.path.join('..','data',f'meds_{codelist_name}.csv'))

WC_missing_ing_tbl
# Out:
#                   id isiddt  isidprev  invalid                        nm
# 0          430306004    NaT       NaN    False        Certolizumab pegol
# 1  39002911000001106    NaT       NaN    False                Filgotinib
# 2  39039711000001109    NaT       NaN    False        Filgotinib maleate
# 3          704313003    NaT       NaN    False               Tofacitinib
# 4          704314009    NaT       NaN    False       Tofacitinib citrate
# 5  37800211000001108    NaT       NaN    False              Upadacitinib
# 6  37949711000001108    NaT       NaN    False  Upadacitinib hemihydrate

# %% [markdown]
# #### Create final list including wildcard ingredient names for ingredients with no exact matches

# %%
sql_incl_wc_match = f'''
SELECT "vmp" AS type, vmp.id, bnf_code, vmp.nm, ing.nm AS ingredient, ddd.ddd
FROM dmd.vmp
INNER JOIN dmd.vpi AS vpi ON vmp.id=vpi.vmp 
INNER JOIN dmd.ing as ing ON ing.id = vpi.ing AND ing.nm IN {names_tuple}
LEFT JOIN dmd.ddd on vmp.id=ddd.vpid

UNION DISTINCT

SELECT "vmp" AS type, vmp.id, bnf_code, vmp.nm, ing.nm AS ingredient, ddd.ddd
FROM dmd.vmp
INNER JOIN dmd.vpi AS vpi ON vmp.id=vpi.vmp 
INNER JOIN dmd.ing as ing ON ing.id = vpi.ing 
LEFT JOIN dmd.ddd on vmp.id=ddd.vpid
WHERE ing.nm LIKE {WC_ing_0}
    OR ing.nm LIKE {WC_ing_1}
    OR ing.nm LIKE {WC_ing_2}
    OR ing.nm LIKE {WC_ing_3}

  '''

meds_incl_wc_match = bq.cached_read(sql_incl_wc_match
            , csv_path=os.path.join('..','data',f'meds_{codelist_name}.csv'))

meds_incl_wc_match

# %% [markdown]
# ### Results

# %%
# How many products have DDDs using exact match
print(meds[["ddd", "id"]].count())

# How many products have DDDs using wildcard matching
print(meds_incl_wc_match[["ddd", "id"]].count())
# Out:
# ddd    38
# id     54
# dtype: int64
# ddd    44
# id     65
# dtype: int64

# %%
meds_incl_wc_match
# Out:
#    type                 id         bnf_code  \
# 0   vmp  38030511000001109             None
# 1   vmp  38067611000001103  1001030AEAAAAAA
# 2   vmp  40087811000001102  1001030AEAAABAB
# 3   vmp  39046311000001104  1001030AGAAABAB
# 4   vmp  39046211000001107  1001030AGAAAAAA
# 5   vmp  39705411000001108  1001030ABAAABAB
# 6   vmp  35734311000001100  1001030ABAAACAC
# 7   vmp  38162311000001103  1001030ABAAADAD
# 8   vmp  17315811000001100  1001030Y0AAAAAA
# 9   vmp  33523711000001105  1001030Y0AAABAB
# 10  vmp  37854811000001107  1001030Y0AAACAC
# 11  vmp  37829111000001100             None
# 12  vmp  37829211000001106             None
# 13  vmp  37829311000001103             None
# 14  vmp  37829511000001109             None
# 15  vmp  37829611000001108             None
# 16  vmp  37829011000001101             None
# 17  vmp  36065711000001105  1001030D0AAABAB
# 18  vmp  16101911000001101  1001030W0AAABAB
# 19  vmp  16102111000001109  1001030W0AAAAAA
# 20  vmp  16102011000001108  1001030W0AAACAC
# 21  vmp  19448611000001101  0801050BCAAAAAA
# 22  vmp  19448511000001100  0801050BCAAABAB
# 23  vmp  19697711000001100  1001030S0AAACAC
# 24  vmp  19946811000001101  1001030D0AAAFAF
# 25  vmp  24856511000001109  0802030F0AAACAC
# 26  vmp  29889211000001106  0802040ATAAAAAA
# 27  vmp  29889111000001100  0802040ATAAABAB
# 28  vmp  30033011000001108  0801050CAAAAAAA
# 29  vmp  34378411000001105  0801050CAAAABAB
# 30  vmp  35541811000001105  0802040ATAAACAC
# 31  vmp  10970211000001102  1001030D0AAACAC
# 32  vmp  11236911000001103  1001030S0AAABAB
# 33  vmp  18038111000001100  1001030X0AAAAAA
# 34  vmp  18038011000001101  1001030X0AAABAB
# 35  vmp  21704711000001107  1001030V0AAABAB
# 36  vmp  23984711000001106  1001030X0AAACAC
# 37  vmp  24856911000001102  1001030W0AAADAD
# 38  vmp  29767011000001106  1001030V0AAACAC
# 39  vmp  32888111000001102  1001030S0AAADAD
# 40  vmp  32888211000001108  1001030S0AAAEAE
# 41  vmp  34742611000001106  1001030ADAAAAAA
# 42  vmp  34742811000001105  1001030ADAAABAB
# 43  vmp  34742511000001107  1001030ADAAACAC
# 44  vmp  34742711000001102  1001030ADAAADAD
# 45  vmp  34840511000001108  1001030D0AAAGAG
# 46  vmp  35318811000001108  1001030S0AAAFAF
# 47  vmp  35431611000001103  1001030W0AAAEAE
# 48  vmp  36458011000001101  1001030S0AAAGAG
# 49  vmp  36457911000001103  1001030S0AAAHAH
# 50  vmp  36441711000001106  1001030S0AAAIAI
# 51  vmp  37223111000001105  1001030V0AAADAD
# 52  vmp  37223011000001109  1001030V0AAAEAE
# 53  vmp  38196111000001103  1001030T0AAACAC
# 54  vmp  38196011000001104  1001030T0AAABAB
# 55  vmp  34346011000001104  1001030ACAAAAAA
# 56  vmp  34625211000001109  1001030ACAAABAB
# 57  vmp  36065611000001101  1001030D0AAAAAA
# 58  vmp          400687000  1001030T0AAAAAA
# 59  vmp  35934711000001107  0802030F0AAABAB
# 60  vmp  35934811000001104  0802030F0AAAAAA
# 61  vmp  11762011000001101  1001030V0AAAAAA
# 62  vmp  35894411000001100  1001030S0AAAAAA
# 63  vmp  11034511000001106  1001030D0AAADAD
# 64  vmp  15987111000001107  1001030D0AAAEAE
#
#                                                                                    nm  \
# 0                                               Upadacitinib hemihydrate 15mg tablets
# 1                                          Upadacitinib 15mg modified-release tablets
# 2                                          Upadacitinib 30mg modified-release tablets
# 3                                                            Filgotinib 200mg tablets
# 4                                                            Filgotinib 100mg tablets
# 5                                                             Tofacitinib 5mg tablets
# 6                                                            Tofacitinib 10mg tablets
# 7                                           Tofacitinib 11mg modified-release tablets
# 8             Certolizumab pegol 200mg/1ml solution for injection pre-filled syringes
# 9   Certolizumab pegol 200mg/1ml solution for injection pre-filled disposable devices
# 10                     Certolizumab pegol 200mg/1ml solution for injection cartridges
# 11                        Rituximab 500mg/500ml in Sodium chloride 0.9% infusion bags
# 12                        Rituximab 600mg/500ml in Sodium chloride 0.9% infusion bags
# 13                        Rituximab 700mg/500ml in Sodium chloride 0.9% infusion bags
# 14                        Rituximab 800mg/500ml in Sodium chloride 0.9% infusion bags
# 15                        Rituximab 900mg/500ml in Sodium chloride 0.9% infusion bags
# 16                       Rituximab 1000mg/500ml in Sodium chloride 0.9% infusion bags
# 17                Etanercept 50mg powder and solvent for solution for injection vials
# 18                                 Tocilizumab 200mg/10ml solution for infusion vials
# 19                                   Tocilizumab 80mg/4ml solution for infusion vials
# 20                                 Tocilizumab 400mg/20ml solution for infusion vials
# 21                                   Ipilimumab 50mg/10ml solution for infusion vials
# 22                                  Ipilimumab 200mg/40ml solution for infusion vials
# 23                                 Adalimumab 40mg/0.8ml solution for injection vials
# 24                Etanercept 10mg powder and solvent for solution for injection vials
# 25                                 Rituximab 1.4g/11.7ml solution for injection vials
# 26                                     Nivolumab 40mg/4ml solution for infusion vials
# 27                                   Nivolumab 100mg/10ml solution for infusion vials
# 28                          Pembrolizumab 50mg powder for solution for infusion vials
# 29                                Pembrolizumab 100mg/4ml solution for infusion vials
# 30                                   Nivolumab 240mg/24ml solution for infusion vials
# 31                     Etanercept 50mg/1ml solution for injection pre-filled syringes
# 32         Adalimumab 40mg/0.8ml solution for injection pre-filled disposable devices
# 33                    Golimumab 50mg/0.5ml solution for injection pre-filled syringes
# 34          Golimumab 50mg/0.5ml solution for injection pre-filled disposable devices
# 35                     Abatacept 125mg/1ml solution for injection pre-filled syringes
# 36           Golimumab 100mg/1ml solution for injection pre-filled disposable devices
# 37                 Tocilizumab 162mg/0.9ml solution for injection pre-filled syringes
# 38           Abatacept 125mg/1ml solution for injection pre-filled disposable devices
# 39         Adalimumab 40mg/0.4ml solution for injection pre-filled disposable devices
# 40                   Adalimumab 40mg/0.4ml solution for injection pre-filled syringes
# 41                  Sarilumab 150mg/1.14ml solution for injection pre-filled syringes
# 42                  Sarilumab 200mg/1.14ml solution for injection pre-filled syringes
# 43        Sarilumab 150mg/1.14ml solution for injection pre-filled disposable devices
# 44        Sarilumab 200mg/1.14ml solution for injection pre-filled disposable devices
# 45         Etanercept 25mg/0.5ml solution for injection pre-filled disposable devices
# 46                   Adalimumab 20mg/0.2ml solution for injection pre-filled syringes
# 47       Tocilizumab 162mg/0.9ml solution for injection pre-filled disposable devices
# 48                   Adalimumab 80mg/0.8ml solution for injection pre-filled syringes
# 49         Adalimumab 80mg/0.8ml solution for injection pre-filled disposable devices
# 50                   Adalimumab 20mg/0.4ml solution for injection pre-filled syringes
# 51                  Abatacept 87.5mg/0.7ml solution for injection pre-filled syringes
# 52                    Abatacept 50mg/0.4ml solution for injection pre-filled syringes
# 53                    Infliximab 120mg/1ml solution for injection pre-filled syringes
# 54          Infliximab 120mg/1ml solution for injection pre-filled disposable devices
# 55                                                            Baricitinib 4mg tablets
# 56                                                            Baricitinib 2mg tablets
# 57                Etanercept 25mg powder and solvent for solution for injection vials
# 58                            Infliximab 100mg powder for solution for infusion vials
# 59                                   Rituximab 100mg/10ml solution for infusion vials
# 60                                   Rituximab 500mg/50ml solution for infusion vials
# 61                             Abatacept 250mg powder for solution for infusion vials
# 62                   Adalimumab 40mg/0.8ml solution for injection pre-filled syringes
# 63                   Etanercept 25mg/0.5ml solution for injection pre-filled syringes
# 64           Etanercept 50mg/1ml solution for injection pre-filled disposable devices
#
#                   ingredient    ddd
# 0   Upadacitinib hemihydrate    NaN
# 1   Upadacitinib hemihydrate    NaN
# 2   Upadacitinib hemihydrate    NaN
# 3         Filgotinib maleate    NaN
# 4         Filgotinib maleate    NaN
# 5        Tofacitinib citrate  10.00
# 6        Tofacitinib citrate  10.00
# 7        Tofacitinib citrate  10.00
# 8         Certolizumab pegol  14.00
# 9         Certolizumab pegol  14.00
# 10        Certolizumab pegol  14.00
# 11                 Rituximab    NaN
# 12                 Rituximab    NaN
# 13                 Rituximab    NaN
# 14                 Rituximab    NaN
# 15                 Rituximab    NaN
# 16                 Rituximab    NaN
# 17                Etanercept   7.00
# 18               Tocilizumab  20.00
# 19               Tocilizumab  20.00
# 20               Tocilizumab  20.00
# 21                Ipilimumab    NaN
# 22                Ipilimumab    NaN
# 23                Adalimumab   2.90
# 24                Etanercept   7.00
# 25                 Rituximab    NaN
# 26                 Nivolumab    NaN
# 27                 Nivolumab    NaN
# 28             Pembrolizumab    NaN
# 29             Pembrolizumab    NaN
# 30                 Nivolumab    NaN
# 31                Etanercept   7.00
# 32                Adalimumab   2.90
# 33                 Golimumab   1.66
# 34                 Golimumab   1.66
# 35                 Abatacept  27.00
# 36                 Golimumab   1.66
# 37               Tocilizumab  20.00
# 38                 Abatacept  27.00
# 39                Adalimumab   2.90
# 40                Adalimumab   2.90
# 41                 Sarilumab  14.30
# 42                 Sarilumab  14.30
# 43                 Sarilumab  14.30
# 44                 Sarilumab  14.30
# 45                Etanercept   7.00
# 46                Adalimumab   2.90
# 47               Tocilizumab  20.00
# 48                Adalimumab   2.90
# 49                Adalimumab   2.90
# 50                Adalimumab   2.90
# 51                 Abatacept  27.00
# 52                 Abatacept  27.00
# 53                Infliximab   3.75
# 54                Infliximab   3.75
# 55               Baricitinib   4.00
# 56               Baricitinib   4.00
# 57                Etanercept   7.00
# 58                Infliximab   3.75
# 59                 Rituximab    NaN
# 60                 Rituximab    NaN
# 61                 Abatacept  27.00
# 62                Adalimumab   2.90
# 63                Etanercept   7.00
# 64                Etanercept   7.00

# %%
meds
# Out:
#    type                 id         bnf_code  \
# 0   vmp  29767011000001106  1001030V0AAACAC
# 1   vmp  21704711000001107  1001030V0AAABAB
# 2   vmp  11762011000001101  1001030V0AAAAAA
# 3   vmp  37223011000001109  1001030V0AAAEAE
# 4   vmp  37223111000001105  1001030V0AAADAD
# 5   vmp  35318811000001108  1001030S0AAAFAF
# 6   vmp  36441711000001106  1001030S0AAAIAI
# 7   vmp  32888111000001102  1001030S0AAADAD
# 8   vmp  32888211000001108  1001030S0AAAEAE
# 9   vmp  11236911000001103  1001030S0AAABAB
# 10  vmp  35894411000001100  1001030S0AAAAAA
# 11  vmp  19697711000001100  1001030S0AAACAC
# 12  vmp  36457911000001103  1001030S0AAAHAH
# 13  vmp  36458011000001101  1001030S0AAAGAG
# 14  vmp  34625211000001109  1001030ACAAABAB
# 15  vmp  34346011000001104  1001030ACAAAAAA
# 16  vmp  19946811000001101  1001030D0AAAFAF
# 17  vmp  36065611000001101  1001030D0AAAAAA
# 18  vmp  34840511000001108  1001030D0AAAGAG
# 19  vmp  11034511000001106  1001030D0AAADAD
# 20  vmp  36065711000001105  1001030D0AAABAB
# 21  vmp  15987111000001107  1001030D0AAAEAE
# 22  vmp  10970211000001102  1001030D0AAACAC
# 23  vmp  23984711000001106  1001030X0AAACAC
# 24  vmp  18038011000001101  1001030X0AAABAB
# 25  vmp  18038111000001100  1001030X0AAAAAA
# 26  vmp          400687000  1001030T0AAAAAA
# 27  vmp  38196011000001104  1001030T0AAABAB
# 28  vmp  38196111000001103  1001030T0AAACAC
# 29  vmp  19448511000001100  0801050BCAAABAB
# 30  vmp  19448611000001101  0801050BCAAAAAA
# 31  vmp  29889111000001100  0802040ATAAABAB
# 32  vmp  35541811000001105  0802040ATAAACAC
# 33  vmp  29889211000001106  0802040ATAAAAAA
# 34  vmp  34378411000001105  0801050CAAAABAB
# 35  vmp  30033011000001108  0801050CAAAAAAA
# 36  vmp  24856511000001109  0802030F0AAACAC
# 37  vmp  37829011000001101             None
# 38  vmp  35934711000001107  0802030F0AAABAB
# 39  vmp  37829111000001100             None
# 40  vmp  35934811000001104  0802030F0AAAAAA
# 41  vmp  37829211000001106             None
# 42  vmp  37829311000001103             None
# 43  vmp  37829511000001109             None
# 44  vmp  37829611000001108             None
# 45  vmp  34742511000001107  1001030ADAAACAC
# 46  vmp  34742611000001106  1001030ADAAAAAA
# 47  vmp  34742711000001102  1001030ADAAADAD
# 48  vmp  34742811000001105  1001030ADAAABAB
# 49  vmp  35431611000001103  1001030W0AAAEAE
# 50  vmp  24856911000001102  1001030W0AAADAD
# 51  vmp  16101911000001101  1001030W0AAABAB
# 52  vmp  16102011000001108  1001030W0AAACAC
# 53  vmp  16102111000001109  1001030W0AAAAAA
#
#                                                                               nm  \
# 0       Abatacept 125mg/1ml solution for injection pre-filled disposable devices
# 1                 Abatacept 125mg/1ml solution for injection pre-filled syringes
# 2                         Abatacept 250mg powder for solution for infusion vials
# 3                Abatacept 50mg/0.4ml solution for injection pre-filled syringes
# 4              Abatacept 87.5mg/0.7ml solution for injection pre-filled syringes
# 5               Adalimumab 20mg/0.2ml solution for injection pre-filled syringes
# 6               Adalimumab 20mg/0.4ml solution for injection pre-filled syringes
# 7     Adalimumab 40mg/0.4ml solution for injection pre-filled disposable devices
# 8               Adalimumab 40mg/0.4ml solution for injection pre-filled syringes
# 9     Adalimumab 40mg/0.8ml solution for injection pre-filled disposable devices
# 10              Adalimumab 40mg/0.8ml solution for injection pre-filled syringes
# 11                            Adalimumab 40mg/0.8ml solution for injection vials
# 12    Adalimumab 80mg/0.8ml solution for injection pre-filled disposable devices
# 13              Adalimumab 80mg/0.8ml solution for injection pre-filled syringes
# 14                                                       Baricitinib 2mg tablets
# 15                                                       Baricitinib 4mg tablets
# 16           Etanercept 10mg powder and solvent for solution for injection vials
# 17           Etanercept 25mg powder and solvent for solution for injection vials
# 18    Etanercept 25mg/0.5ml solution for injection pre-filled disposable devices
# 19              Etanercept 25mg/0.5ml solution for injection pre-filled syringes
# 20           Etanercept 50mg powder and solvent for solution for injection vials
# 21      Etanercept 50mg/1ml solution for injection pre-filled disposable devices
# 22                Etanercept 50mg/1ml solution for injection pre-filled syringes
# 23      Golimumab 100mg/1ml solution for injection pre-filled disposable devices
# 24     Golimumab 50mg/0.5ml solution for injection pre-filled disposable devices
# 25               Golimumab 50mg/0.5ml solution for injection pre-filled syringes
# 26                       Infliximab 100mg powder for solution for infusion vials
# 27     Infliximab 120mg/1ml solution for injection pre-filled disposable devices
# 28               Infliximab 120mg/1ml solution for injection pre-filled syringes
# 29                             Ipilimumab 200mg/40ml solution for infusion vials
# 30                              Ipilimumab 50mg/10ml solution for infusion vials
# 31                              Nivolumab 100mg/10ml solution for infusion vials
# 32                              Nivolumab 240mg/24ml solution for infusion vials
# 33                                Nivolumab 40mg/4ml solution for infusion vials
# 34                           Pembrolizumab 100mg/4ml solution for infusion vials
# 35                     Pembrolizumab 50mg powder for solution for infusion vials
# 36                            Rituximab 1.4g/11.7ml solution for injection vials
# 37                  Rituximab 1000mg/500ml in Sodium chloride 0.9% infusion bags
# 38                              Rituximab 100mg/10ml solution for infusion vials
# 39                   Rituximab 500mg/500ml in Sodium chloride 0.9% infusion bags
# 40                              Rituximab 500mg/50ml solution for infusion vials
# 41                   Rituximab 600mg/500ml in Sodium chloride 0.9% infusion bags
# 42                   Rituximab 700mg/500ml in Sodium chloride 0.9% infusion bags
# 43                   Rituximab 800mg/500ml in Sodium chloride 0.9% infusion bags
# 44                   Rituximab 900mg/500ml in Sodium chloride 0.9% infusion bags
# 45   Sarilumab 150mg/1.14ml solution for injection pre-filled disposable devices
# 46             Sarilumab 150mg/1.14ml solution for injection pre-filled syringes
# 47   Sarilumab 200mg/1.14ml solution for injection pre-filled disposable devices
# 48             Sarilumab 200mg/1.14ml solution for injection pre-filled syringes
# 49  Tocilizumab 162mg/0.9ml solution for injection pre-filled disposable devices
# 50            Tocilizumab 162mg/0.9ml solution for injection pre-filled syringes
# 51                            Tocilizumab 200mg/10ml solution for infusion vials
# 52                            Tocilizumab 400mg/20ml solution for infusion vials
# 53                              Tocilizumab 80mg/4ml solution for infusion vials
#
#        ingredient    ddd
# 0       Abatacept  27.00
# 1       Abatacept  27.00
# 2       Abatacept  27.00
# 3       Abatacept  27.00
# 4       Abatacept  27.00
# 5      Adalimumab   2.90
# 6      Adalimumab   2.90
# 7      Adalimumab   2.90
# 8      Adalimumab   2.90
# 9      Adalimumab   2.90
# 10     Adalimumab   2.90
# 11     Adalimumab   2.90
# 12     Adalimumab   2.90
# 13     Adalimumab   2.90
# 14    Baricitinib   4.00
# 15    Baricitinib   4.00
# 16     Etanercept   7.00
# 17     Etanercept   7.00
# 18     Etanercept   7.00
# 19     Etanercept   7.00
# 20     Etanercept   7.00
# 21     Etanercept   7.00
# 22     Etanercept   7.00
# 23      Golimumab   1.66
# 24      Golimumab   1.66
# 25      Golimumab   1.66
# 26     Infliximab   3.75
# 27     Infliximab   3.75
# 28     Infliximab   3.75
# 29     Ipilimumab    NaN
# 30     Ipilimumab    NaN
# 31      Nivolumab    NaN
# 32      Nivolumab    NaN
# 33      Nivolumab    NaN
# 34  Pembrolizumab    NaN
# 35  Pembrolizumab    NaN
# 36      Rituximab    NaN
# 37      Rituximab    NaN
# 38      Rituximab    NaN
# 39      Rituximab    NaN
# 40      Rituximab    NaN
# 41      Rituximab    NaN
# 42      Rituximab    NaN
# 43      Rituximab    NaN
# 44      Rituximab    NaN
# 45      Sarilumab  14.30
# 46      Sarilumab  14.30
# 47      Sarilumab  14.30
# 48      Sarilumab  14.30
# 49    Tocilizumab  20.00
# 50    Tocilizumab  20.00
# 51    Tocilizumab  20.00
# 52    Tocilizumab  20.00
# 53    Tocilizumab  20.00
